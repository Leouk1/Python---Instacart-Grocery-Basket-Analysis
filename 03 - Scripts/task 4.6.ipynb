# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/leo/Desktop/Career Foundry/Achievement 4/Instacart Basket Analysis 30:10:25'

# %%
# Importing orders_products_combined from pkl format
orders_products_combined = pd.read_pickle(os.path.join(path, '02 - Data', 'prepared Data', 'orders_products_combined.pkl'))

# %%
# Importing products data 
products_cleaned_4_5 = pd.read_csv(os.path.join(path, '02 - Data', 'prepared Data', 'products_cleaned_4.5.csv'),index_col = False)

# %%
# Check Shape
orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
products_cleaned_4_5.shape
# Out:
# (49672, 5)

# %% [markdown]
# # 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  First_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
products_cleaned_4_5.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ## I will use the df.merge() to combine the 2 data sets on = product_id

# %%
#test the merge wihtout overwriting
pd.merge(orders_products_combined, products_cleaned_4_5, on = ['product_id'], indicator='Match')
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2539329        1    prior             1          2
# 2          2539329        1    prior             1          2
# 3          2539329        1    prior             1          2
# 4          2539329        1    prior             1          2
# ...            ...      ...      ...           ...        ...
# 32404854   2977660   206209    prior            13          1
# 32404855   2977660   206209    prior            13          1
# 32404856   2977660   206209    prior            13          1
# 32404857   2977660   206209    prior            13          1
# 32404858   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  First_order  product_id  \
# 0                         8                     NaN         True         196
# ...

# %% [markdown]
# # There are 2 things I need to address.
# 1. Remove merge column from orders_products_combined
# 2. Remove the eval_set column

# %%
# Drop columns
orders_products_combined = orders_products_combined.drop(columns=['eval_set','_merge'])

# %%
# Check output
orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  First_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# 1                     NaN         True       14084                  2
# 2                     NaN         True       12427                  3
# 3                     NaN         True       26088                  4
# 4                     NaN         True       26405                  5
#
#    reordered
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
orders_products_combined.shape
# Out:
# (32434489, 10)

# %% [markdown]
# ## Now time for merge

# %%
#merge updated DataFrame
df_ords_prods_merge = products_cleaned_4_5.merge(orders_products_combined, on = 'product_id', indicator = True)

# %%
# Check output
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   3139998      138            28          6                 11
# 1   1977647      138            30          6                 17
# 2    389851      709             2          0                 21
# 3    652770      764             1          3                 13
# 4   1813452      764             3          4                 17
#
#    days_since_prior_order  First_order  add_to_cart_order  reordered _merge
# ...

# %%
#check the shape
df_ords_prods_merge.shape
# Out:
# (32404859, 15)

# %% [markdown]
# # 6. Confirm the results of the merge using the merge flag.

# %%
#checking the result of merge using merge flag
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # 7. Export the newly created dataframe as ords_prods_merge in a suitable format (taking into consideration the size).

# %%
# Export data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02 - Data','Prepared Data', 'ords_prods_merge.pkl'))
